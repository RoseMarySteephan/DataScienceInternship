# %%
# Step 1: Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap

# Step 2: Load dataset
df = pd.read_csv("synthetic_accident_data.csv")
df.head()
# Out:
#    ID        Date   Time Weather Road_Condition  Severity  Latitude  Longitude
# 0   1  2023-01-13  08:39   Clear            Dry         3   40.6919   -87.5997
# 1   2  2023-04-04  21:19    Snow            Dry         2   32.7944   -95.3115
# 2   3  2023-05-07  17:09   Clear            Dry         3   32.7319   -95.3741
# 3   4  2023-05-19  23:19   Clear            Wet         3   39.7170   -95.3655
# 4   5  2023-02-13  02:04    Rain            Icy         3   32.8165   -87.6441

# %%
# Convert Date and Time columns
df['Date'] = pd.to_datetime(df['Date'])
df['Hour'] = pd.to_datetime(df['Time'], format='%H:%M').dt.hour

# %%
sns.histplot(df['Hour'], bins=24, kde=False)
plt.title("Accidents by Hour of Day")
plt.xlabel("Hour")
plt.ylabel("Number of Accidents")
plt.grid(True)
plt.show()

# %%
weather_counts = df['Weather'].value_counts()
sns.barplot(x=weather_counts.index, y=weather_counts.values)
plt.title("Accidents by Weather Condition")
plt.xlabel("Weather")
plt.ylabel("Number of Accidents")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
road_counts = df['Road_Condition'].value_counts()
sns.barplot(x=road_counts.index, y=road_counts.values)
plt.title("Accidents by Road Condition")
plt.xlabel("Road Condition")
plt.ylabel("Number of Accidents")
plt.grid(True)
plt.show()

# %%
severity_counts = df['Severity'].value_counts().sort_index()
sns.barplot(x=severity_counts.index, y=severity_counts.values)
plt.title("Accident Severity Distribution")
plt.xlabel("Severity Level")
plt.ylabel("Count")
plt.grid(True)
plt.show()

# %%
sns.countplot(data=df, x='Severity', hue='Weather_Condition', order=sorted(df['Severity'].unique()))
plt.title('Accident Severity vs Weather Conditions')
plt.xticks(rotation=0)
plt.legend([],[], frameon=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-267855160> in <cell line: 0>()
# ----> 1 sns.countplot(data=df, x='Severity', hue='Weather_Condition', order=sorted(df['Severity'].unique()))
#       2 plt.title('Accident Severity vs Weather Conditions')
#       3 plt.xticks(rotation=0)
#       4 plt.legend([],[], frameon=False)
#       5 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2629         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2630
# -> 2631     p = _CategoricalAggPlotter(
#    2632         data=data,
#    2633         variables=dict(x=x, y=y, hue=hue),
#
# ...
